# %% [markdown]
# # Extracting Restaurant Data

# %% [markdown]
# Author: Jonatan Amaya

# %% [markdown]
# The provided code uses the Google Places API (new) to gather detailed information about restaurants within a specified district (in our case, San Isidro). It includes initializing the API with essential parameters, processing district and department data (Peru shapefile), extracting and structuring restaurant information, outputting the data to JSON and CSV files, and visually representing the restaurant locations on a map.

# %% [markdown]
# - <a href='#1'> 1. Google Places API (new)  </a>
#     - <a href='#1.1'> 1.1 Class to interact with the Google Places API (new)  </a>
#     - <a href='#1.2'> 1.2 District selecion  </a>
#     - <a href='#1.3'> 1.3 Restaurant details  </a>
#     - <a href='#1.4'> 1.4 Output (json, csv) </a>
#     - <a href='#1.5'> 1.5 Geospatial visualization of places </a>
#
# - <a href='#2'> 2. EXTRA: Google Places API (old)  </a>
#     - <a href='#2.1'> 2.1 Class to interact with the Google Places API (new)  </a>
#     - <a href='#2.2'> 2.2 District selecion  </a>
#     - <a href='#2.3'> 2.3 Restaurant details  </a>
#     - <a href='#2.4'> 2.4 Output (json, csv) </a>
#     - <a href='#2.5'> 2.5 Geospatial visualization of places </a>

# %% [markdown]
# ### Libraries

# %%
import json
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point
import requests
import datetime
import random
import googlemaps

# %% [markdown]
# ### Auxiliary functions

# %%
# Function to format a review text for improved readability
def format_review(text):
    # Remove line breaks and duplicate periods
    text = text.replace('\n', ' ').replace('. .', '.')
    
    # Split the text into sentences
    sentences = text.split('. ')
    
    # Remove additional whitespace around sentences
    sentences = [sentence.strip() for sentence in sentences]
    
    # Capitalize the first letter of each sentence
    formatted_sentences = []
    for sentence in sentences:
        if sentence:
            formatted_sentence = sentence[0].upper() + sentence[1:]
            formatted_sentences.append(formatted_sentence)
    
    # Construct the formatted text
    if len(formatted_sentences) == 1:
        formatted_text = text
    else:
        formatted_text = '. '.join(formatted_sentences)
        
    # Add a period at the end if formatted_text does not end with a punctuation mark
    if formatted_text[-1] not in ['.', '!', '?']:
        formatted_text += '.'
    
    return formatted_text

# Function to determine if a restaurant point is inside the district polygon
def is_inside_district(restaurant_point, district_polygon):
    return district_polygon.contains(restaurant_point)

# %% [markdown]
# # <a id='1'> 1. Google Places API (new)

# %% [markdown]
# The new version of the Google Places API gives you access to more than 200 million businesses and points of interest, including an expanded list of place details and types. Show users new place attributes such real-time data for EV charging stations, wheelchair accessible establishments, and whether a restaurant allows dogs. Updates also include an enhanced search experience, modern security with OAuth-based authentication, and simplifications to pricing.
# Link: https://console.cloud.google.com/apis/library/places.googleapis.com

# %% [markdown]
# ## <a id='1.1'> 1.1 Class to interact with the Google Places API (new)

# %%
class GooglePlacesAPI:
    def __init__(self, api_key):
        # Initialize the Google Places API with the provided API key and URL
        self.api_key = api_key
        self.url_textsearch = 'https://places.googleapis.com/v1/places:searchText'
        self.url_nearbysearch= 'https://places.googleapis.com/v1/places:searchNearby'
        
        # Define parameters to include in the API response
        parameters = (
            'places.displayName,'
            'places.formattedAddress,'
            'places.id,'
            'places.location,'
            'places.nationalPhoneNumber,'
            'places.rating,'
            'places.websiteUri,'
            'places.reviews,'
            'places.regularOpeningHours'
        )
        
        # Set request headers including content type, API key, and field mask
        self.headers = {
            'Content-Type': 'application/json',
            'X-Goog-Api-Key': self.api_key,
            'X-Goog-FieldMask': parameters
        }
        
        self.gmaps = googlemaps.Client(key=api_key)

    def text_search(self, query):
        # Define the data payload for the POST request
        data = {
            'textQuery': query,
            'languageCode': 'es',
            'includedType': 'restaurant',
            'strictTypeFiltering': True,
            'regionCode': 'PE',
            'maxResultCount': 3 # 3 places
        }

        # Make the POST request to the Google Places API
        response = requests.post(self.url_textsearch, headers=self.headers, json=data)

        # Parse the JSON response
        json_response = response.json()

        # Extract places from the response
        places = json_response.get('places', [])

        # Filter places that are located within district according to the Peru shapefile
        district_places = []
        for place in places:
            restaurant_point = Point(place['location']['longitude'], place['location']['latitude'])
            if is_inside_district(restaurant_point, district_polygon):
                district_places.append(place)

        # Return three places
        return district_places
    
    def nearby_search(self, latitude, longitude, radius):
        # Define the data payload for the POST request
        data = {
                  "includedPrimaryTypes": "restaurant",
                  "maxResultCount": 3, #3 places
                  "languageCode": "es",
                  "regionCode": "PE",
                  "locationRestriction": {
                    "circle": {
                      "center": {
                        "latitude": latitude,
                        "longitude": longitude},
                      "radius": radius
                    }
                  }
               }

        # Make the POST request to the Google Places API
        response = requests.post(self.url_nearbysearch, headers=self.headers, json=data)

        # Parse the JSON response
        json_response = response.json()

        # Extract places from the response
        places = json_response.get('places', [])


        # Filter places that are located within district according to the Peru shapefile
        district_places = []
        for place in places:
            restaurant_point = Point(place['location']['longitude'], place['location']['latitude'])
            if is_inside_district(restaurant_point, district_polygon):
                district_places.append(place)

        # Return three places
        return district_places
  
    
    def get_district_coordinates(self, district_department):
        # Geocode 
        district = self.gmaps.geocode(district_department)
        
        # Extract coordinates
        if district:
            geo_coordinates = district[0]['geometry']['location']
            lat_district = geo_coordinates['lat']
            lng_district = geo_coordinates['lng']
            return lat_district, lng_district
        else:
            return None

# %% [markdown]
# ## <a id='1.2'> 1.2 District selection

# %%
# District name. Please use the form: "District, Department"
district_department= "San Isidro, Lima"
district_name, department_name = [part.strip().upper() for part in district_department.split(',')]


# Load the Peru shapefile
maps = gpd.read_file(r'../../data/shape_file/DISTRITOS.shp')
maps = maps[maps['DEPARTAMEN'] == department_name][['geometry', 'DISTRITO']]
district_polygon = maps.loc[maps['DISTRITO'] == district_name, 'geometry'].iloc[0]

# API Key
google_places = GooglePlacesAPI("AIzaSyClMsx-xgsKKMnpqNmE7SsP4jj6ADOZI98")

# Option 1: Text search
#places = google_places.text_search(f"Restaurantes en {district_department}")

# Option 2: Nearby search


district_coordinates = google_places.get_district_coordinates(district_department)

radius = 1000.0

places = google_places.nearby_search(district_coordinates[0],district_coordinates[1],radius)

# %% [markdown]
# ## <a id='1.3'> 1.3 Restaurant details

# %%
# Initialize the list of restaurant information
restaurants_info = []

# Iterate over the found restaurants
for place in places:
    # Extract restaurant information
    restaurant_details = {
        'name': place.get('displayName', {}).get('text', ''),  # Extract name
        'address': place.get('formattedAddress', ''),  # Extract address
        'phone_number': place.get('nationalPhoneNumber', ''),  # Extract phone number
        'website': place.get('websiteUri', ''),  # Extract website
        'rating': place.get('rating', ''),  # Extract rating
        'opening_hours': {},  # Initialize opening hours dictionary
        'reviews': {}  # Initialize reviews dictionary
    }
    
    # If there is information about opening hours, format and add it to the restaurant details
    if 'regularOpeningHours' in place:
        opening_hours = place['regularOpeningHours']['periods']
        for period in opening_hours:
            open_time = datetime.datetime.strptime(f"{period['open']['hour']}:{period['open']['minute']}", "%H:%M").strftime("%I:%M %p")
            close_time = datetime.datetime.strptime(f"{period['close']['hour']}:{period['close']['minute']}", "%H:%M").strftime("%I:%M %p")
            day = ['monday', 'tuesday', 'wednesday', 'thursday', 'friday', 'saturday', 'sunday'][period['open']['day']]
            restaurant_details['opening_hours'][day] = f"{open_time} - {close_time}"
    
    # If there is review information, add it to the restaurant details
    if 'reviews' in place:
        for idx, review in enumerate(place['reviews'], start=1):
            review_text = format_review(review['originalText']['text'])
            author_name = review['authorAttribution']['displayName'].title()
            review_info = {
                'author': author_name,  # Review author name
                'text': review_text,  # Review text
                'rating': review['rating']  # Review rating
            }
            restaurant_details['reviews'][f'number_{idx}'] = review_info

    # Add restaurant details to the list
    restaurants_info.append(restaurant_details)

# %% [markdown]
# ## <a id='1.4'> 1.4 Output (json, csv)

# %%
restaurants_info
# Out:
# [{'name': 'Astrid y Gastón',
#   'address': 'Av. Paz Soldán 290, San Isidro 15073',
#   'phone_number': '(01) 4422777',
#   'website': 'http://www.astridygaston.com/',
#   'rating': 4.6,
#   'opening_hours': {'monday': '12:00 PM - 04:00 PM',
#    'wednesday': '07:00 PM - 10:30 PM',
#    'thursday': '07:00 PM - 10:30 PM',
#    'friday': '07:00 PM - 10:30 PM',
#    'saturday': '07:00 PM - 10:30 PM',
#    'sunday': '07:00 PM - 10:30 PM'},
#   'reviews': {'number_1': {'author': 'Luis Fernando Garcia',
#     'text': 'Llegamos con muchas espectativas ya que estabamos llendo a uno de los mejores restaurantes de Peru. Sin embargo varias cosas no cumplieron nuestras espectativas. Primero, el lugar es muy bello por fuera, sin embargo en la mesa al interior donde nos ubicaron habia un olor muy fuerte a cañeria y baño. Por otra parte, cuando mi esposa solicito que se le informase que platos no eran picantes, el mesero solo dijo que todos los platos en peru tienen aroma de aji... Y no respondio la pregunta especifica. La comida, estaba bien y con muy buena presentacion, sin embargo nada fuera de lo comun respecto a lo que probamos en otros restaurantes de Peru.',
#     'rating': 3},
#    'number_2': {'author': 'Andrea Moyano',
#     'text': 'Excelente atención del personal y ambiente cálido y agradable! La comida, no nos sorprendió. Entradas pequeñas. Platos principales, normales. Muy cuidados los detalles,  tanto en el lugar como en cada plato que llega a la mesa. Precios elevados.',
#     'rating': 3},
#    'number_3': {'author': 'Guillermo Gómez',
#     'text': 'Sencillamemte espectacular. El lugar, el servicio y la comida, inigualables. Los tacos de cuy estaban buenísimos, el camarón de Río delicioso y el cochinillo es increíble. Es un lugar para repetir tantas veces como se pueda; es más, vale la pena ir a Lima solo por este restaurante.',
#     'rating': 5},
#    'number_4': {'author': 'Emma Fernández Fernández',
#     'text': 'Buen ambiente y servicio, sin embargo esperábamos más de un lugar con este renombre. Muchos de los platos nos dejaron bastante decepcionados: entradas como la vichyssoise o el ceviche de alcachofa no estaban demasiado logrados, el arroz es una mala reinterpretation de una paella española, desde luego el punto del arroz estaba pasadísimo y el mero estaba demasiado cocinado, si bien su salsa y el tamal que lo acompañaba era fantástico. Los postres también nos dejaron bastante decepcionados, tanto el chocolate como la cheesecake no destacaron en absoluto, desgraciadamente. Su cesta de panes es un triunfo, sin duda, pero en un restaurante de esta categoría el pan no debería despuntar por encima de sus propuestas. Calidad precio no lo recomendaría.',
#     'rating': 3},
#    'number_5': {'author': 'Emanuel Arias',
#     'text': 'Excelente, unos de los mejores restaurantes de Lima, podría decir de todo Perú. Muy buena experiencia desde que llegas hasta que te vas. Están atentos en casa detalle. El ambiente es muy bueno, visualmente es único. La comida es excelente. Totalmente recomendado ⭐⭐⭐⭐⭐.',
#     'rating': 5}}},
#  {'name': 'Osaka',
#   'address': 'Felipe, Av. Pardo y Aliaga 660, San Isidro 15073',
#   'phone_number': '(01) 2220405',
#   'website': 'http://www.osakanikkei.com/',
#   'rating': 4.7,
#   'opening_hours': {'monday': '12:30 PM - 10:30 PM',
#    'tuesday': '12:30 PM - 12:00 AM',
#    'wednesday': '12:30 PM - 12:00 AM',
#    'thursday': '12:30 PM - 12:00 AM',
#    'friday': '12:30 PM - 12:00 AM',
#    'saturday': '12:30 PM - 12:00 AM',
#    'sunday': '12:30 PM - 12:00 AM'},
#   'reviews': {'number_1': {'author': 'Juan Lozano',
#     'text': '¡¡Excelente!!. La comida es muy buena, variada y sorprendente. La atención rápida, cálida y amable. El local agradable, con un ambiente ameno. Celebré mi cumpleaños allá y me lo festejaron. Un restaurante para volver sin duda.',
#     'rating': 5},
#    'number_2': {'author': 'Mijail Carpio',
#     'text': 'El restaurante Osaka ofrece un ambiente sumamente sofisticado, donde se percibe la perfecta fusión entre la cocina peruana y japonesa. Los platos son excepcionales, logrando una armonía única entre el estilo japonés y los sabores peruanos. Se recomienda hacer reservas y mencionar cualquier alergia al ordenar para una experiencia culinaria sin contratiempos y llena de sabores cautivadores.',
#     'rating': 4},
#    'number_3': {'author': 'Alfonso Cortes',
#     'text': 'Lugar con gran diseño y buena comida pero servicio deficiente para el nivel y precio. Meseros no saben la carta, no están atentos a nuevos pedidos. Comida japonesa fusión peruana, los mejores platillos son los acevichados. En general buen lugar, pero el servicio tiene muchas áreas de oportunidad.',
#     'rating': 4},
#    'number_4': {'author': 'Andrea Moyano',
#     'text': 'La cena no fue lo esperado. La comida Kuroi ramen: escasa, los mariscos muy pocos, eran decorativos y los fideos ramen estaban pegados a la sarten y secos. Las bebidas sin alcohol: sin sabor, puro hielo. Las entradas: muy diminutas. Además, trajeron primero el plato de fondo y luego la entrada. La experiencia fue completamente distinta a la de la noche anterior que asistimos, donde nos atendió un mozo Gonzalo, que fue muy servicial y explicó con detalle cada plato. La segunda noche fue una completa desilusión, además, los precios son elevados. Ambiente y decoración: muy bueno.',
#     'rating': 3},
#    'number_5': {'author': 'Mike De Llano',
#     'text': 'De los mejores restaurantes japoneses a los que he ido sin duda. Toda la comida está espectacular. La única queja es el servicio que nos tocó, al mesero se le olvidaron varios platillos y bebidas, pero aún así merece 5 estrellas el lugar.',
#     'rating': 5}}},
#  {'name': 'Primos Chicken Bar San Isidro',
#   'address': 'Av. Los Conquistadores 201, San Isidro 15073',
#   'phone_number': '(01) 6804049',
#   'website': 'http://www.primoschickenbar.pe/',
#   'rating': 4.4,
#   'opening_hours': {'monday': '12:00 PM - 10:30 PM',
#    'tuesday': '12:00 PM - 10:30 PM',
#    'wednesday': '12:00 PM - 10:30 PM',
#    'thursday': '12:00 PM - 10:30 PM',
#    'friday': '12:00 PM - 10:30 PM',
#    'saturday': '12:00 PM - 11:00 PM',
#    'sunday': '12:00 PM - 11:00 PM'},
#   'reviews': {'number_1': {'author': 'Asiole Garcia',
#     'text': 'Al llegar la chica que estaba en la puerta de abajo siendo discapacitada no me permitía entrar. Mi hijo le tuvo que explicar que no podía subir escaleras. Luego tardaron en limpiar una mesa vacía mientras esperaba y al final no la limpiaron y me mandaron a otra mas lejos para mi problema de rodillas. Tampoco recibí atención sino de un señor que si fue amable. Pero tardaba porque estaba solo para todas las mesas. Una de las chicas hablaba con la cajera y no le importaba los clientes. Muy insatisfecha de la atención de la joven del día 8 de Enero en la tarde 2pm.',
#     'rating': 3},
#    'number_2': {'author': 'Cristhian F Hernandez S',
#     'text': 'Ligar muy bueno para comer un buen pollo a las brasas. Es agradable el lugar y bien decorado. La porción es llenadora. Yo lo acompañe con una buena jarra de chicha.',
#     'rating': 5},
#    'number_3': {'author': 'Patricia Sanchez Loyola',
#     'text': 'Tenia altas expectativas sobre esta pollería, sin embargo habiendo tenido la oportunidad de haber probado en varias pollerias anteriores,  siento que no es tan espectacular como se menciona , si es agradable pero para que te haga sentir un sabor único,  yo diría que no, cuestión de cada uno, particularmente según el precio actual está 33 soles el 1/4 de pollo , siento que no esta a la altura , por otro lado, el servicio fue rápido y no tuve problemas al encontrar mesa, en conclusión bueno.',
#     'rating': 4},
#    'number_4': {'author': 'Daniel G',
#     'text': 'Restaurante especializado en pollo a la brasa, ofrecen carnes a la parrilla, hamburguesas, chicken crispers y piquéis variados de buena calidad y porción. Sabor agradable, local bien presentado. Es difícil encontrar estacionamiento pero no imposible. Lo único malo es la bulla que se escucha en uno de los salones. Deberían implementar algún diseño acústico que permita reducir la bulla generada por la cantidad de personas en el salón. Existe buena relación calidad precio. Cabe resaltar la mayonesa que ofrecen para acompañar es muy sabrosa.',
#     'rating': 4},
#    'number_5': {'author': 'Marisella Hoyos',
#     'text': 'El ambiente es muy bonito y grande. La atención por parte de los mozos muy buena , atentos y amables .Regresare , lo recomiendo.',
#     'rating': 5}}}]

# %%
# Output

# Lowering
district_name_lower = district_name.lower()
department_name_lower = department_name.lower()

# Part 1: Save information to a JSON file
with open(f'../../output/restaurants_info_{district_name_lower}_{department_name_lower}.json', 'w', encoding='utf-8') as f:
    json.dump(restaurants_info, f, indent=4, ensure_ascii=False)

# Part 2: Create a CSV file from JSON information
df = pd.json_normalize(restaurants_info)  # Convert nested JSON to flat DataFrame
df.to_csv(f'../../output/restaurants_info_{district_name_lower}_{department_name_lower}.csv', index=False, encoding='utf-8-sig')

# %%
#Dataframe
df
# Out:
#                             name  \
# 0                Astrid y Gastón
# 1                          Osaka
# 2  Primos Chicken Bar San Isidro
#
#                                             address  phone_number  \
# 0              Av. Paz Soldán 290, San Isidro 15073  (01) 4422777
# 1  Felipe, Av. Pardo y Aliaga 660, San Isidro 15073  (01) 2220405
# 2      Av. Los Conquistadores 201, San Isidro 15073  (01) 6804049
#
#                            website  rating opening_hours.monday  \
# 0    http://www.astridygaston.com/     4.6  12:00 PM - 04:00 PM
# 1      http://www.osakanikkei.com/     4.7  12:30 PM - 10:30 PM
# 2  http://www.primoschickenbar.pe/     4.4  12:00 PM - 10:30 PM
#
#   opening_hours.wednesday opening_hours.thursday opening_hours.friday  \
# 0     07:00 PM - 10:30 PM    07:00 PM - 10:30 PM  07:00 PM - 10:30 PM
# 1     12:30 PM - 12:00 AM    12:30 PM - 12:00 AM  12:30 PM - 12:00 AM
# 2     12:00 PM - 10:30 PM    12:00 PM - 10:30 PM  12:00 PM - 10:30 PM
#
#   opening_hours.saturday  ...  reviews.number_3.author  \
# 0    07:00 PM - 10:30 PM  ...          Guillermo Gómez
# 1    12:30 PM - 12:00 AM  ...           Alfonso Cortes
# 2    12:00 PM - 11:00 PM  ...  Patricia Sanchez Loyola
#
#                                reviews.number_3.text reviews.number_3.rating  \
# 0  Sencillamemte espectacular. El lugar, el servi...                       5
# 1  Lugar con gran diseño y buena comida pero serv...                       4
# 2  Tenia altas expectativas sobre esta pollería, ...                       4
#
#     reviews.number_4.author  \
# 0  Emma Fernández Fernández
# 1             Andrea Moyano
# 2                  Daniel G
#
#                                reviews.number_4.text reviews.number_4.rating  \
# 0  Buen ambiente y servicio, sin embargo esperába...                       3
# 1  La cena no fue lo esperado. La comida Kuroi ra...                       3
# 2  Restaurante especializado en pollo a la brasa,...                       4
#
#    reviews.number_5.author                              reviews.number_5.text  \
# 0            Emanuel Arias  Excelente, unos de los mejores restaurantes de...
# 1            Mike De Llano  De los mejores restaurantes japoneses a los qu...
# 2          Marisella Hoyos  El ambiente es muy bonito y grande. La atenció...
#
#   reviews.number_5.rating  opening_hours.tuesday
# 0                       5                    NaN
# 1                       5    12:30 PM - 12:00 AM
# 2                       5    12:00 PM - 10:30 PM
#
# [3 rows x 27 columns]

# %% [markdown]
# ## <a id='1.5'> 1.5 Geospatial visualization of restaurants

# %%
# Plot

# Create a dictionary to assign a unique color to each restaurant
restaurant_colors = {}
for idx, place in enumerate(places):
    restaurant_name = place.get('displayName', {}).get('text', '')
    restaurant_colors[restaurant_name] = f'C{idx}'  # Use Matplotlib colors

# District map
district_map = maps[maps['DISTRITO'] == district_name]

# Plot district polygon
fig, ax = plt.subplots(figsize=(10, 10))
district_map.plot(ax=ax, color='lightblue', edgecolor='black')

# Plot restaurants with names and colors
for place in places:
    lat, lon = place['location']['latitude'], place['location']['longitude']
    name = place.get('displayName', {}).get('text', '')
    color = restaurant_colors[name]
    
    ax.scatter(lon, lat, color=color, label=name)  # Point for the restaurant

# Add legend below the image
plt.legend(loc='lower left', bbox_to_anchor=(0.0, -0.3), ncol=2)

# Additional plot settings
ax.set_title(f'Restaurants in {district_department}')
plt.xticks(rotation=45)
plt.tight_layout()

# Save plot as high-quality image
plt.savefig(f'../../output/restaurants_{district_name_lower}_{department_name_lower}_map.png', dpi=300)

# Show plot
plt.show()

# %% [markdown]
# # <a id='2'> 2. EXTRA: Google Places API (old)

# %% [markdown]
# Get data from the same database used by Google Maps. Places features over 100 million businesses and points of interest that are updated frequently through owner-verified listings and user-moderated contributions.
# Link: https://console.cloud.google.com/marketplace/product/google/places-backend.googleapis.com

# %% [markdown]
# ## <a id='2.1'> 2.1 Class to interact with the Google Places API (old)

# %%
class GooglePlaces(object):
    def __init__(self, apiKey):
        self.apiKey = apiKey
        self.gmaps = googlemaps.Client(key=self.apiKey)

    def search_places_by_coordinate(self, location, radius, types):
        endpoint_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
        places = []
        params = {
            'location': location,
            'radius': radius,
            'type': types,
            'key': self.apiKey,
            'language': 'es'  # Specify language as Spanish
        }
        res = requests.get(endpoint_url, params=params)
        results = json.loads(res.content)
        places.extend(results['results'][:3])  # Limit to first 3 places
        return places
    
    def text_search_old(self, query, location, types):
        endpoint_url = "https://maps.googleapis.com/maps/api/place/textsearch/json"
        places = []
        params = {
            'query': query,
            'location': location,
            'type': types,
            'key': self.apiKey,
            'language': 'es'  # Specify language as Spanish
        }
        res = requests.get(endpoint_url, params=params)
        results = json.loads(res.content)
        places.extend(results['results'])  
        
        # Filter places that are located within district according to the Peru shapefile
        places_in_district = []
        for place in places:
            details = self.get_place_details(place['place_id'], fields)
            point = Point(details['result']['geometry']['location']['lng'], details['result']['geometry']['location']['lat'])
            if is_inside_district(point, district_polygon):
                places_in_district.append(place)
        
        # Return the first 3 places in the district
        return places_in_district[:3]

    def get_place_details(self, place_id, fields):
        endpoint_url = "https://maps.googleapis.com/maps/api/place/details/json"
        params = {
            'place_id': place_id,
            'fields': ",".join(fields),
            'key': self.apiKey,
            'language': 'es'  # Specify language as Spanish
        }
        res = requests.get(endpoint_url, params=params)
        place_details = json.loads(res.content)
        return place_details

    def get_district_coordinates(self, district_department):
        # Geocode 
        district = self.gmaps.geocode(district_department)
        
        # Extract coordinates
        if district:
            geo_coordinates = district[0]['geometry']['location']
            lat_district = geo_coordinates['lat']
            lng_district = geo_coordinates['lng']
            return lat_district, lng_district
        else:
            return None

# %% [markdown]
# ## <a id='2.2'> 2.2 District selection

# %%
# District name. Please use the form: "District, Department"
district_department= "San Isidro, Lima"
district_name, department_name = [part.strip().upper() for part in district_department.split(',')]


# Load the Peru shapefile
maps = gpd.read_file(r'../../data/shape_file/DISTRITOS.shp')
maps = maps[maps['DEPARTAMEN'] == department_name][['geometry', 'DISTRITO']]
district_polygon = maps.loc[maps['DISTRITO'] == district_name, 'geometry'].iloc[0]

# API Key
google_places = GooglePlaces("AIzaSyC7nVxA_-00iMv7fnNkErI8zSeshb7C4ek")

# Fields
fields = ['name', 'formatted_address', 'international_phone_number', 'website', 'rating', 'review', 'opening_hours', 'geometry']

# Option 1: Text search
places = google_places.text_search_old(f"Restaurantes en {district_department}", district_department, "restaurant")

# Option 2: Nearby search

#district_coordinates = google_places.get_district_coordinates(district_department)

#radius = 500

#places = google_places.search_places_by_coordinate(f"{district_coordinates[0]},{district_coordinates[1]}", radius, "restaurant")

# %% [markdown]
# ## <a id='2.3'> 2.3 Restaurant details

# %%
restaurants_info = []


# Iterate over the found restaurants
for place in places:
    # Get details of the restaurant
    details = google_places.get_place_details(place['place_id'], fields)
    
    # Extract restaurant information
    restaurant_details = {
        'name': details['result'].get('name', ''),
        'address': details['result'].get('formatted_address', ''),
        'phone_number': details['result'].get('international_phone_number', ''),
        'website': details['result'].get('website', ''),
        'rating': details['result'].get('rating', ''),
        'opening_hours': {},  # Initialize opening hours dictionary
        'reviews': {}  # Initialize reviews dictionary
    }
    
    # If there are opening hours information, format and add it to the restaurant details
    if 'opening_hours' in details['result']:
        opening_hours = details['result']['opening_hours']['periods']
        for period in opening_hours:
            open_time = datetime.datetime.strptime(period['open']['time'], "%H%M").strftime("%I:%M %p")
            close_time = datetime.datetime.strptime(period['close']['time'], "%H%M").strftime("%I:%M %p")
            day = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'][period['open']['day']]
            restaurant_details['opening_hours'][f'{day}'] = f"{open_time} - {close_time}"
    
    # If there are reviews, add them to the restaurant details
    if 'reviews' in details['result']:
        for idx, review in enumerate(details['result']['reviews'], start=1):
            review_text=format_review(review['text'])
            author_name=review['author_name'].title()
            restaurant_details['reviews'][f'{idx}_author'] = author_name
            restaurant_details['reviews'][f'{idx}_text'] = review_text
            restaurant_details['reviews'][f'{idx}_rating'] = review['rating']
    
    # Add restaurant details to the list
    restaurants_info.append(restaurant_details)

# %% [markdown]
# ## <a id='2.4'> 2.4 Output (json, csv)

# %%
restaurants_info
# Out:
# [{'name': 'Callao Bistro',
#   'address': 'Av. Dos de Mayo 561, San Isidro 15073, Perú',
#   'phone_number': '+51 922 002 447',
#   'website': '',
#   'rating': 4.3,
#   'opening_hours': {'Monday': '09:30 AM - 07:00 PM',
#    'Tuesday': '09:30 AM - 07:00 PM',
#    'Wednesday': '09:30 AM - 10:30 PM',
#    'Thursday': '09:30 AM - 10:30 PM',
#    'Friday': '09:30 AM - 10:30 PM',
#    'Saturday': '09:30 AM - 10:30 PM',
#    'Sunday': '09:30 AM - 10:30 PM'},
#   'reviews': {'1_author': 'Sebastián Llosa',
#    '1_text': 'Precio altos (la mayoria de platos por encima de los 50-60 soles) y el sabor deja mucho que desear. No me parece que tenga una buena relación precio-calidad, por esto no es un restaurante al que volveria. El ambiente si es bonito y tranquilo.',
#    '1_rating': 2,
#    '2_author': 'Fiorela Figueroa Anccasi',
#    '2_text': 'Bonito lugar, algo caro, pero de buen sabor. El baño era muy pequeño, entendible por el lugar.',
#    '2_rating': 4,
#    '3_author': 'Luis Arturo Gensollen Kaisen',
#    '3_text': 'Pésimo servicio, platos caros y desabridos, no confiar en Google para estas cosas gastronómicas, solo entramos por la fachada que se veía agradable. No recomendado de nuestra parte además dejamos parte del almuerzo por el sabor desagradable. Agrego que estuve enfermo por 2 días del estómago por comer aquí.',
#    '3_rating': 1,
#    '4_author': 'Oscar Walking',
#    '4_text': 'Muy buen sandwich de pejerrey frito arrebozado con papas fritas y deliciosos calamares fritos. Alitas fritas y anticuchos muy buenos también. Excelente y atento servicio. Totalmente Recomendado !',
#    '4_rating': 5,
#    '5_author': 'Nicolas Curro',
#    '5_text': 'Lindo lugar, local pequeño pero bien decorado. La comida estuvo muy buena pedimos una Orgia Marina muy bien servida qué nos permitió probar un poco de todo. Excelente su pan con pejerrey y buena porción. Precios un poco elevados pero vale la pena. Volveré luego del verano para seguir probando sus platos. Recomendable.',
#    '5_rating': 5}},
#  {'name': 'Nanka',
#   'address': 'C. Manuel Bañón 260, San Isidro 15073, Perú',
#   'phone_number': '+51 994 294 931',
#   'website': 'http://www.nanka.pe/',
#   'rating': 4.6,
#   'opening_hours': {'Monday': '12:30 PM - 05:30 PM',
#    'Tuesday': '12:30 PM - 10:30 PM',
#    'Wednesday': '12:30 PM - 10:30 PM',
#    'Thursday': '12:30 PM - 10:30 PM',
#    'Friday': '12:30 PM - 10:30 PM',
#    'Saturday': '12:30 PM - 10:30 PM',
#    'Sunday': '12:30 PM - 10:30 PM'},
#   'reviews': {'1_author': 'Laura Chavez',
#    '1_text': 'El lugar me gusto, estuvimos en la terraza. El personal calificado un 10. El almuerzo estuvo muy al gusto, calidad y fresco.',
#    '1_rating': 5,
#    '2_author': 'Michelle Abregú',
#    '2_text': 'Pedimos pizza con vegetales, raviolis de seco de pato, arroz acevichado con pato, una porción de papas nativas y bolitas de quinua como entrada. Todo estuvo bien, aunque los raviolis y el seco de pato destacaron entre los demás platos. Lo único malo fue que no había en el menú su famoso lomo saltado, fuimos un jueves y no había carnes ese día. La atención es buena, el local es bonito y los precios son razonables (varían entre 39-79 soles por plato).',
#    '2_rating': 4,
#    '3_author': 'Nicole Lavanchy',
#    '3_text': 'Buen restaurante, con muy buena decoración, comida riquísima y excelente atención. La carta es pequeña, y tiene propuestas de platos muy interesantes, con sabores que se hacen notar e ingredientes orgánicos. Me llamo la atención mucho que un porcentaje del valor de mi plato, iba destinado en ayuda a una fundación. La carta de tragos y líquidos es buena. Lo otro, que me pareció buenísimo, es la servicial, atenta y preparada atención del personal. Me parece una muy buena alternativa de restaurante, con precios muy asequibles. Lo recomiendo muchísimo.',
#    '3_rating': 5,
#    '4_author': 'Guillermo Delgado',
#    '4_text': 'Nanka siempre es Nanka. Un lugar donde cada plato es una sorpresa más exquisita que la anterior. Presentación de primera con sabores excepcionales que no se encuentran en ningún otro lado. Son capaces de reinventar un plato tan clásico como el cebiche y otorgarle un toque único. Obras de arte que el paladar agradece con jolgorio.',
#    '4_rating': 5,
#    '5_author': 'Alice Zymelka',
#    '5_text': '𝙁𝙤𝙤𝙙 / 𝘾𝙤𝙢𝙞𝙙𝙖: ⭐⭐⭐⭐⭐ 5/5 𝘿𝙧𝙞𝙣𝙠𝙨 / 𝘽𝙚𝙗𝙞𝙙𝙖𝙨: ⭐⭐⭐⭐⭐ 5/5 𝙎𝙚𝙧𝙫𝙞𝙘𝙚 / 𝘼𝙩𝙚𝙣𝙘𝙞ó𝙣: ⭐⭐⭐⭐ 4/5 𝙋𝙧𝙤𝙩𝙤𝙘𝙤𝙡𝙨 / 𝙋𝙧𝙤𝙩𝙤𝙘𝙤𝙡𝙤𝙨: Regular 𝙉𝙤𝙞𝙨𝙚 𝙡𝙚𝙫𝙚𝙡 / 𝙉𝙞𝙫𝙚𝙡 𝙙𝙚 𝙧𝙪𝙞𝙙𝙤: ⭐⭐⭐ 3/5  ⒺⓈ:  Un lugar muy agradable para almorzar. Intente reservar una mesa afuera, será menos ruidoso. El restaurante está abierto en algunas partes y ofrece una buena ventilación si te sientas dentro. El nivel de ruido en el interior era un poco alto. El personal era muy amable, pero tomó un poco de tiempo para hacer nuestros pedidos. La presentación de la comida es muy hermosa y la comida sabe muy bien: el menú ofrece una buena variedad de platos para elegir. ⒺⓃ:  Very nice place to have lunch at - try to book a table outside, it will be less noisy. The restaurant is open at some parts and gives a good ventilation if you sit inside though. The noise level inside was a bit to loud. The staff was very friendly but it took a bit if time to place our orders. The food presentation is very beautiful and the food tastes really good - the menu offers a good variety of dishes to chose from.',
#    '5_rating': 4}},
#  {'name': 'El Hornero',
#   'address': 'Av. Dos de Mayo 758, San Isidro 15073, Perú',
#   'phone_number': '+51 1 4210162',
#   'website': 'http://www.elhornero.com.pe/',
#   'rating': 4.5,
#   'opening_hours': {'Monday': '11:30 AM - 10:00 PM',
#    'Tuesday': '11:30 AM - 12:00 AM',
#    'Wednesday': '11:30 AM - 12:00 AM',
#    'Thursday': '11:30 AM - 12:00 AM',
#    'Friday': '11:30 AM - 12:00 AM',
#    'Saturday': '11:30 AM - 12:00 AM',
#    'Sunday': '11:30 AM - 12:00 AM'},
#   'reviews': {'1_author': 'Claudia Bermudez Utor',
#    '1_text': 'La comida estuvo bien, las pastas muy ricas la verdad. Hacia muchísimo calor en el local y el aire acondicionado funcionaba mal, era un poco insoportable. Al llegar te ponen una canasta de pan "que no has pedido" y después te la cobran como consumo por cada persona sin siquiera consultarte o informarte. La próxima vez que me hagan eso voy a denunciarlos antes Indecopi.',
#    '1_rating': 3,
#    '2_author': 'Gianella Chapoñan',
#    '2_text': 'Muy agradable lugar, siempre que estoy en Lima, paso por este lugar, tiene unos cortes de carne muy buenos y deliciosos 🫶 La atención super rápida y cordial sobretodo. Super recomendado 😍.',
#    '2_rating': 5,
#    '3_author': 'Willy Cano Alatrista',
#    '3_text': 'Buen lugar, bastante concurrido. La comida deliciosa. Los meseros parecen atentos, pero creo que solo eso… parecen o lo son selectivamente. Pedimos una porción extra de papas que demoraron demasiado, lo mismo con la cuenta. La comida muy buena. La atención no me gustó.',
#    '3_rating': 3,
#    '4_author': 'Marco Ramirez',
#    '4_text': 'Buena opción de carnes. Mejorar ventilación y aire acondicionado. Mejorar servicio, tuvimos que pedir 3 veces la carta de postres. Incorporar salsas adicionales para acompañar la carne. Creo que para almuerzo, la opción de 2 de mayo resulta poco atractiva, regresaré a Chorrillos.',
#    '4_rating': 3,
#    '5_author': 'José Carrillo',
#    '5_text': 'Nada Del otro mundo. La atención bajo bastante, se pidió término medio, la trajeron muy cocida. La atención nada buena.',
#    '5_rating': 3}}]

# %%
# Output

# Lowering
district_name_lower = district_name.lower()
department_name_lower = department_name.lower()

# Part 1: Save information to a JSON file
with open(f'../../output/restaurants_info_{district_name_lower}_{department_name_lower}_old.json', 'w', encoding='utf-8') as f:
    json.dump(restaurants_info, f, indent=4, ensure_ascii=False)

# Part 2: Create a CSV file from JSON information
df = pd.json_normalize(restaurants_info)  # Convert nested JSON to flat DataFrame
df.to_csv(f'../../output/restaurants_info_{district_name_lower}_{department_name_lower}_old.csv', index=False, encoding='utf-8-sig')

# %%
df
# Out:
#             name                                      address  \
# 0  Callao Bistro  Av. Dos de Mayo 561, San Isidro 15073, Perú
# 1          Nanka  C. Manuel Bañón 260, San Isidro 15073, Perú
# 2     El Hornero  Av. Dos de Mayo 758, San Isidro 15073, Perú
#
#       phone_number                       website  rating opening_hours.Monday  \
# 0  +51 922 002 447                                   4.3  09:30 AM - 07:00 PM
# 1  +51 994 294 931          http://www.nanka.pe/     4.6  12:30 PM - 05:30 PM
# 2    +51 1 4210162  http://www.elhornero.com.pe/     4.5  11:30 AM - 10:00 PM
#
#   opening_hours.Tuesday opening_hours.Wednesday opening_hours.Thursday  \
# 0   09:30 AM - 07:00 PM     09:30 AM - 10:30 PM    09:30 AM - 10:30 PM
# 1   12:30 PM - 10:30 PM     12:30 PM - 10:30 PM    12:30 PM - 10:30 PM
# 2   11:30 AM - 12:00 AM     11:30 AM - 12:00 AM    11:30 AM - 12:00 AM
#
#   opening_hours.Friday  ... reviews.2_rating              reviews.3_author  \
# 0  09:30 AM - 10:30 PM  ...                4  Luis Arturo Gensollen Kaisen
# 1  12:30 PM - 10:30 PM  ...                4               Nicole Lavanchy
# 2  11:30 AM - 12:00 AM  ...                5          Willy Cano Alatrista
#
#                                       reviews.3_text reviews.3_rating  \
# 0  Pésimo servicio, platos caros y desabridos, no...                1
# 1  Buen restaurante, con muy buena decoración, co...                5
# 2  Buen lugar, bastante concurrido. La comida del...                3
#
#     reviews.4_author                                     reviews.4_text  \
# 0      Oscar Walking  Muy buen sandwich de pejerrey frito arrebozado...
# 1  Guillermo Delgado  Nanka siempre es Nanka. Un lugar donde cada pl...
# 2      Marco Ramirez  Buena opción de carnes. Mejorar ventilación y ...
#
#   reviews.4_rating  reviews.5_author  \
# 0                5     Nicolas Curro
# 1                5     Alice Zymelka
# 2                3     José Carrillo
#
#                                       reviews.5_text reviews.5_rating
# 0  Lindo lugar, local pequeño pero bien decorado....                5
# 1  𝙁𝙤𝙤𝙙 / 𝘾𝙤𝙢𝙞𝙙𝙖: ⭐⭐⭐⭐⭐ 5/5 𝘿𝙧𝙞𝙣𝙠𝙨 / 𝘽𝙚𝙗𝙞𝙙𝙖𝙨: ⭐⭐⭐...                4
# 2  Nada Del otro mundo. La atención bajo bastante...                3
#
# [3 rows x 27 columns]

# %% [markdown]
# ## <a id='2.5'> 2.5 Geospatial visualization of restaurants

# %%
# Plot

# Create a dictionary to assign a unique color to each restaurant
restaurant_colors = {}
for idx, place in enumerate(places):
    restaurant_name = place.get('name', '')  # Use the restaurant name from the place
    restaurant_colors[restaurant_name] = f'C{idx}'  # Use Matplotlib colors

# District map
district_map = maps[maps['DISTRITO'] == district_name]

# Plot district polygon
fig, ax = plt.subplots(figsize=(10, 10))
district_map.plot(ax=ax, color='lightblue', edgecolor='black')

# Plot restaurants with names and colors
for place in places:
    lat, lon = place['geometry']['location']['lat'], place['geometry']['location']['lng']
    name = place.get('name', '')  # Use the restaurant name from the place
    color = restaurant_colors[name]
    
    ax.scatter(lon, lat, color=color, label=name)  # Point for the restaurant

# Add legend below the image
plt.legend(loc='lower left', bbox_to_anchor=(0.0, -0.3), ncol=2)

# Additional plot settings
ax.set_title(f'Restaurants in {district_department}')
plt.xticks(rotation=45)
plt.tight_layout()

# Save plot as high-quality image
plt.savefig(f'../../output/restaurants_{district_name_lower}_{department_name_lower}_map_old.png', dpi=300)

# Show plot
plt.show()
